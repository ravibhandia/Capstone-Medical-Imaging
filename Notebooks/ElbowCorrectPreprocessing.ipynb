# %% [markdown]
# # Training Classifier Elbow

# %%
# !pip install -U --pre efficientnet
# Out:
# Collecting efficientnet
#   Downloading https://files.pythonhosted.org/packages/53/97/84f88e581d6ac86dcf1ab347c497c4c568c38784e3a2bd659b96912ab793/efficientnet-1.1.1-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet) (0.16.2)
# Collecting keras-applications<=1.0.8,>=1.0.7
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 4.4MB/s
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (1.1.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (2.5)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (7.0.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (1.4.1)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (2.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (3.2.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.18.5)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.10.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet) (4.4.2)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (1.2.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.15.0)
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import tensorflow as tf
import cv2

import seaborn as sns
from PIL import Image

from tqdm import tqdm_notebook,tqdm


from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16,preprocess_input,decode_predictions
from keras.layers import  Convolution2D,MaxPooling2D,Dense,Flatten,Dropout,GlobalMaxPooling1D
from keras.layers import AveragePooling2D
from keras.models import  Sequential
import imutils
from keras.applications.resnet import ResNet50,ResNet152,preprocess_input,decode_predictions
from keras.applications.densenet import DenseNet121,DenseNet169,preprocess_input,decode_predictions
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
import efficientnet.keras as efn

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Generating MetaDataframes

# %%
def returnDf(bodypart,path):

  train_imgs_path=pd.read_csv(path+'MURA-v1.1/train_image_paths.csv',names=['img_path'])
  test_imgs_path=pd.read_csv(path+'MURA-v1.1/valid_image_paths.csv',names=['img_path'])


  train_imgs_path['Body_Part']=train_imgs_path['img_path'].apply(lambda x: str(x.split('/')[2])[3:])
  train_imgs_path['Study_No']=train_imgs_path['img_path'].apply(lambda x: str(x.split('/')[4])[:6])
  train_imgs_path['label']=train_imgs_path['img_path'].apply(lambda x: str(x.split('/')[4])[7:])

  test_imgs_path['Body_Part']=test_imgs_path['img_path'].apply(lambda x: str(x.split('/')[2])[3:])
  test_imgs_path['Study_No']=test_imgs_path['img_path'].apply(lambda x: str(x.split('/')[4])[:6])
  test_imgs_path['label']=test_imgs_path['img_path'].apply(lambda x: str(x.split('/')[4])[7:])


  train_df=train_imgs_path[train_imgs_path['Body_Part']==bodypart]
  test_df=test_imgs_path[test_imgs_path['Body_Part']==bodypart]

  train_df['img_path']=[path + i for i in train_df['img_path']]
  test_df['img_path']=[path + i for i in test_df['img_path']]
  
  #train_labels['Body_Part']=train_labels['img_path'].apply(lambda x: str(x.split('/')[2])[3:])
  #train_labels['Study_Type']=train_labels['img_path'].apply(lambda x: str(x.split('/')[4])[:6])
  #test_labels['Body_Part']=test_labels['img_path'].apply(lambda x: str(x.split('/')[2])[3:])
  #test_labels['Study_Type']=test_labels['img_path'].apply(lambda x: str(x.split('/')[4])[:6])


  #train_labels['img_path']=train_imgs_path.iloc[:,0]
  #test_labels['img_path']=test_imgs_path.iloc[:,0]
    
  #train_df=train_labels[train_labels['Body_Part']==bodypart]
  #test_df=test_labels[test_labels['Body_Part']==bodypart]
  #train_df['img_path']=[path + i for i in train_df['img_path']]
  #train_df['label']=train_df['label'].astype('str')
  #test_df['img_path']=[path + i for i in test_df['img_path']]
  #test_df['label']=test_df['label'].astype('str')
  train_df['label']=[str(1) if i=='positive' else str(0) for i in train_df['label']]
  test_df['label']=[str(1) if i=='positive' else str(0) for i in test_df['label']]

  return train_df, test_df

# %%
train_df,test_df=returnDf('ELBOW','gdrive/My Drive/Capstone Medical Imaging/Data.nosync/')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_df.head()
# Out:
#                                                 img_path  ... label
# 14757  gdrive/My Drive/Capstone Medical Imaging/Data....  ...     1
# 14758  gdrive/My Drive/Capstone Medical Imaging/Data....  ...     1
# 14759  gdrive/My Drive/Capstone Medical Imaging/Data....  ...     1
# 14760  gdrive/My Drive/Capstone Medical Imaging/Data....  ...     1
# 14761  gdrive/My Drive/Capstone Medical Imaging/Data....  ...     1
#
# [5 rows x 4 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4931 entries, 14757 to 19687
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   img_path   4931 non-null   object
#  1   Body_Part  4931 non-null   object
#  2   Study_No   4931 non-null   object
#  3   label      4931 non-null   object
# dtypes: object(4)
# memory usage: 192.6+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 465 entries, 2271 to 2735
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   img_path   465 non-null    object
#  1   Body_Part  465 non-null    object
#  2   Study_No   465 non-null    object
#  3   label      465 non-null    object
# dtypes: object(4)
# memory usage: 18.2+ KB

# %%
 train_df['img_path'].iloc[1]
# Out:
# 'gdrive/My Drive/Capstone Medical Imaging/Data.nosync/MURA-v1.1/train/XR_ELBOW/patient04904/study1_positive/image1.png'

# %%
train_df['label'].value_counts()
# Out:
# 0    2925
# 1    2006
# Name: label, dtype: int64

# %%
test_df['label'].value_counts()
# Out:
# 0    235
# 1    230
# Name: label, dtype: int64

# %% [markdown]
# Baseline accuracy on training is 59%

# %%
mean_imagenet = [0.485, 0.456, 0.406]
std_imagenet = [0.229, 0.224, 0.225]

# %%
train_df.head().iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x7f29dd95c780>

# %%
fig,ax=plt.subplots(5,2,sharey=True,figsize=(20,100))
image_dict={}
image_dict['images']=[]
image_dict['label']=[]
count=0
for index,row in tqdm(train_df.head().iterrows()):
  img_arr=cv2.imread(row['img_path'])
  ax[count,0].imshow(img_arr)
  
  resized_arr=cv2.resize(img_arr,(224,224))
  
  ax[count,1].imshow(resized_arr)
  count+=1
                     
  

#image_dict['images']=(image_dict['images']-mean_imagenet)/std_imagenet
# Out:
# 5it [00:14,  2.85s/it]

# %% [markdown]
# # Creating image generators with simple preprocessing and options for data augmentation

# %%
def returnImgGen(train_df,test_df,IMG_SIZE=(224,224),rotation_range=0,horizontal_flip=False):
  datagen=ImageDataGenerator(
    horizontal_flip=horizontal_flip,
    #vertical_flip=True,
    rotation_range=rotation_range,
    #fill_mode='nearest',
    #preprocessing_function=preprocess_input)
    rescale=1./255.)



  train_gen=datagen.flow_from_dataframe(train_df,
                           x_col='img_path',
                           y_col='label',
                           target_size=IMG_SIZE,
                           color_mode='rgb',
                           class_mode='binary',batch_size=8,seed=101)

  
    
  val_gen=datagen.flow_from_dataframe(test_df,
                           x_col='img_path',
                           y_col='label',
                           target_size=IMG_SIZE,
                           color_mode='rgb',
                           class_mode='binary', batch_size=1,seed=101)
    
    
  return train_gen, val_gen

# %%
train_gen_224,val_gen_224=returnImgGen(train_df,test_df)
# Out:
# Found 4931 validated image filenames belonging to 2 classes.
# Found 465 validated image filenames belonging to 2 classes.

# %%
def plot_val_train_loss(hist):
  loss_train = hist.history['loss']
  loss_val = hist.history['val_loss']
  epochs = range(1,len(hist.history['val_loss'])+1)
  plt.plot(epochs, loss_train, 'g', label='Training loss')
  plt.plot(epochs, loss_val, 'b', label='validation loss')
  plt.title('Training and Validation loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()

# %% [markdown]
# # Augmented Data Image Generators

# %%
train_gen_aug,val_gen_aug=returnImgGen(train_df,test_df,IMG_SIZE=(224,224),rotation_range=30,horizontal_flip=True)
# Out:
# Found 4931 validated image filenames belonging to 2 classes.
# Found 465 validated image filenames belonging to 2 classes.

# %% [markdown]
# # DenseNet169 with Augmentation

# %%
weight_path="{}_weights.best.hdf5".format('best_densenet_elbow_classifier')

checkpoint3 = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)


reduceLROnPlat3 = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto', min_lr=0.000001)
#epsilon=0.0001, cooldown=5
early3 = EarlyStopping(monitor='val_loss', patience=10, verbose=1, min_delta=1e-4) # probably needs to be more patient, but kaggle time is limited
callbacks_list_3 = [checkpoint3, early3, reduceLROnPlat3]

opt=keras.optimizers.Adam(learning_rate=0.001)
model17=Sequential()
model17.add(DenseNet169(include_top=False,weights='imagenet',input_shape=(224,224,3),pooling='avg'))
model17.add(Flatten())
model17.add(Dense(1, activation='sigmoid'))
model17.compile(loss='binary_crossentropy',optimizer=opt,metrics = ['accuracy','mse'])
model17.summary()

history17=model17.fit(train_gen_aug,validation_data=val_gen_aug,epochs=30,callbacks=callbacks_list_3,shuffle=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet169 (Functional)     (None, 1664)              12642880
# _________________________________________________________________
# flatten (Flatten)            (None, 1664)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1665
# =================================================================
# Total params: 12,644,545
# Trainable params: 12,486,145
# Non-trainable params: 158,400
# _________________________________________________________________
# Epoch 1/30
# 617/617 [==============================] - ETA: 0s - loss: 0.7037 - accuracy: 0.5822 - mse: 0.2478
# Epoch 00001: val_loss improved from inf to 1.87540, saving model to best_densenet_elbow_classifier_weights.best.hdf5
# 617/617 [==============================] - 2307s 4s/step - loss: 0.7037 - accuracy: 0.5822 - mse: 0.2478 - val_loss: 1.8754 - val_accuracy: 0.5054 - val_mse: 0.3195
# Epoch 2/30
# 617/617 [==============================] - ETA: 0s - loss: 0.6791 - accuracy: 0.5875 - mse: 0.2403
# Epoch 00002: val_loss improved from 1.87540 to 0.68064, saving model to best_densenet_elbow_classifier_weights.best.hdf5
# 617/617 [==============================] - 86s 140ms/step - loss: 0.6791 - accuracy: 0.5875 - mse: 0.2403 - val_loss: 0.6806 - val_accuracy: 0.5140 - val_mse: 0.2437
# Epoch 3/30
# 617/617 [==============================] - ETA: 0s - loss: 0.6762 - accuracy: 0.5954 - mse: 0.2391
# Epoch 00003: val_loss did not improve from 0.68064
# 617/617 [==============================] - 84s 137ms/step - loss: 0.6762 - accuracy: 0.5954 - mse: 0.2391 - val_loss: 0.7964 - val_accuracy: 0.4710 - val_mse: 0.2966
# Epoch 4/30
# 617/617 [==============================] - ETA: 0s - loss: 0.6787 - accuracy: 0.5835 - mse: 0.2416
# Epoch 00004: val_loss did not improve from 0.68064
# 617/617 [==============================] - 84s 136ms/step - loss: 0.6787 - accuracy: 0.5835 - mse: 0.2416 - val_loss: 10.0288 - val_accuracy: 0.5957 - val_mse: 0.2813
# Epoch 5/30
# 617/617 [==============================] - ETA: 0s - loss: 0.6789 - accuracy: 0.5893 - mse: 0.2403
# Epoch 00005: val_loss did not improve from 0.68064
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 617/617 [==============================] - 85s 137ms/step - loss: 0.6789 - accuracy: 0.5893 - mse: 0.2403 - val_loss: 1.1816 - val_accuracy: 0.5699 - val_mse: 0.2861
# Epoch 6/30
# 617/617 [==============================] - ETA: 0s - loss: 0.6485 - accuracy: 0.6224 - mse: 0.2282
# Epoch 00006: val_loss did not improve from 0.68064
# 617/617 [==============================] - 84s 136ms/step - loss: 0.6485 - accuracy: 0.6224 - mse: 0.2282 - val_loss: 0.7387 - val_accuracy: 0.5183 - val_mse: 0.2632
# Epoch 7/30
# 617/617 [==============================] - ETA: 0s - loss: 0.6412 - accuracy: 0.6333 - mse: 0.2249
# Epoch 00007: val_loss did not improve from 0.68064
# 617/617 [==============================] - 83s 134ms/step - loss: 0.6412 - accuracy: 0.6333 - mse: 0.2249 - val_loss: 0.7192 - val_accuracy: 0.5312 - val_mse: 0.2596
# Epoch 8/30
# 617/617 [==============================] - ETA: 0s - loss: 0.6259 - accuracy: 0.6583 - mse: 0.2176
# Epoch 00008: val_loss improved from 0.68064 to 0.67851, saving model to best_densenet_elbow_classifier_weights.best.hdf5
# 617/617 [==============================] - 87s 141ms/step - loss: 0.6259 - accuracy: 0.6583 - mse: 0.2176 - val_loss: 0.6785 - val_accuracy: 0.5957 - val_mse: 0.2407
# Epoch 9/30
# 617/617 [==============================] - ETA: 0s - loss: 0.6175 - accuracy: 0.6686 - mse: 0.2140
# Epoch 00009: val_loss did not improve from 0.67851
# 617/617 [==============================] - 86s 139ms/step - loss: 0.6175 - accuracy: 0.6686 - mse: 0.2140 - val_loss: 0.8758 - val_accuracy: 0.6000 - val_mse: 0.2509
# Epoch 10/30
# 617/617 [==============================] - ETA: 0s - loss: 0.6088 - accuracy: 0.6788 - mse: 0.2098
# Epoch 00010: val_loss improved from 0.67851 to 0.64734, saving model to best_densenet_elbow_classifier_weights.best.hdf5
# 617/617 [==============================] - 85s 137ms/step - loss: 0.6088 - accuracy: 0.6788 - mse: 0.2098 - val_loss: 0.6473 - val_accuracy: 0.6366 - val_mse: 0.2146
# Epoch 11/30
# 617/617 [==============================] - ETA: 0s - loss: 0.5943 - accuracy: 0.6974 - mse: 0.2036
# Epoch 00011: val_loss did not improve from 0.64734
# 617/617 [==============================] - 84s 136ms/step - loss: 0.5943 - accuracy: 0.6974 - mse: 0.2036 - val_loss: 0.7369 - val_accuracy: 0.6473 - val_mse: 0.2236
# Epoch 12/30
# 617/617 [==============================] - ETA: 0s - loss: 0.5836 - accuracy: 0.7039 - mse: 0.1989
# Epoch 00012: val_loss did not improve from 0.64734
# 617/617 [==============================] - 83s 135ms/step - loss: 0.5836 - accuracy: 0.7039 - mse: 0.1989 - val_loss: 0.9586 - val_accuracy: 0.6473 - val_mse: 0.2533
# Epoch 13/30
# 617/617 [==============================] - ETA: 0s - loss: 0.5803 - accuracy: 0.7015 - mse: 0.1981
# Epoch 00013: val_loss improved from 0.64734 to 0.56748, saving model to best_densenet_elbow_classifier_weights.best.hdf5
# 617/617 [==============================] - 85s 138ms/step - loss: 0.5803 - accuracy: 0.7015 - mse: 0.1981 - val_loss: 0.5675 - val_accuracy: 0.7011 - val_mse: 0.1934
# Epoch 14/30
# 617/617 [==============================] - ETA: 0s - loss: 0.5634 - accuracy: 0.7244 - mse: 0.1896
# Epoch 00014: val_loss did not improve from 0.56748
# Epoch 23/30
# 617/617 [==============================] - ETA: 0s - loss: 0.4732 - accuracy: 0.7873 - mse: 0.1534
# Epoch 00023: val_loss improved from 0.48414 to 0.44408, saving model to best_densenet_elbow_classifier_weights.best.hdf5
# 617/617 [==============================] - 83s 134ms/step - loss: 0.4732 - accuracy: 0.7873 - mse: 0.1534 - val_loss: 0.4441 - val_accuracy: 0.7957 - val_mse: 0.1442
# Epoch 24/30
# 617/617 [==============================] - ETA: 0s - loss: 0.4687 - accuracy: 0.7895 - mse: 0.1515
# Epoch 00024: val_loss did not improve from 0.44408
# 617/617 [==============================] - 83s 134ms/step - loss: 0.4687 - accuracy: 0.7895 - mse: 0.1515 - val_loss: 0.4568 - val_accuracy: 0.7828 - val_mse: 0.1495
# Epoch 25/30
# 617/617 [==============================] - ETA: 0s - loss: 0.4681 - accuracy: 0.7968 - mse: 0.1511
# Epoch 00025: val_loss did not improve from 0.44408
# 617/617 [==============================] - 82s 133ms/step - loss: 0.4681 - accuracy: 0.7968 - mse: 0.1511 - val_loss: 0.4509 - val_accuracy: 0.7785 - val_mse: 0.1495
# Epoch 26/30
# 617/617 [==============================] - ETA: 0s - loss: 0.4751 - accuracy: 0.7879 - mse: 0.1536
# Epoch 00026: val_loss did not improve from 0.44408
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 617/617 [==============================] - 82s 132ms/step - loss: 0.4751 - accuracy: 0.7879 - mse: 0.1536 - val_loss: 0.4576 - val_accuracy: 0.7849 - val_mse: 0.1504
# Epoch 27/30
# 617/617 [==============================] - ETA: 0s - loss: 0.4630 - accuracy: 0.7940 - mse: 0.1492
# Epoch 00027: val_loss improved from 0.44408 to 0.43907, saving model to best_densenet_elbow_classifier_weights.best.hdf5
# 617/617 [==============================] - 82s 133ms/step - loss: 0.4630 - accuracy: 0.7940 - mse: 0.1492 - val_loss: 0.4391 - val_accuracy: 0.7957 - val_mse: 0.1447
# Epoch 28/30
# 617/617 [==============================] - ETA: 0s - loss: 0.4632 - accuracy: 0.7976 - mse: 0.1488
# Epoch 00028: val_loss did not improve from 0.43907
# 617/617 [==============================] - 83s 134ms/step - loss: 0.4632 - accuracy: 0.7976 - mse: 0.1488 - val_loss: 0.4634 - val_accuracy: 0.7892 - val_mse: 0.1483
# Epoch 29/30
# 617/617 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.7952 - mse: 0.1496
# Epoch 00029: val_loss did not improve from 0.43907
# 617/617 [==============================] - 82s 133ms/step - loss: 0.4636 - accuracy: 0.7952 - mse: 0.1496 - val_loss: 0.4405 - val_accuracy: 0.7914 - val_mse: 0.1443
# Epoch 30/30
# 617/617 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.7929 - mse: 0.1509
# Epoch 00030: val_loss did not improve from 0.43907
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1e-06.
# 617/617 [==============================] - 82s 133ms/step - loss: 0.4675 - accuracy: 0.7929 - mse: 0.1509 - val_loss: 0.4408 - val_accuracy: 0.7914 - val_mse: 0.1433

# %%
plot_val_train_loss(history17)

# %%
from google.colab import files
files.download("best_densenet_elbow_classifier_weights.best.hdf5")

# %%
model17.load_weights('best_densenet_elbow_classifier_weights.best.hdf5')

# %%
Y_pred = model17.predict(val_gen_aug)

# %%
predictions = []
for p in Y_pred:
    if(p > 0.5):
        predictions+=[1]
    else:
        predictions+=[0]

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print('Confusion Matrix')
print(confusion_matrix(val_gen_aug.classes, predictions))
print('Classification Report')
target_names = ['Normal','Abnormal']
print(classification_report(val_gen_aug.classes, predictions, target_names=target_names))
# Out:
# Confusion Matrix
# [[141  94]
#  [148  82]]
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.49      0.60      0.54       235
#     Abnormal       0.47      0.36      0.40       230
#
#     accuracy                           0.48       465
#    macro avg       0.48      0.48      0.47       465
# weighted avg       0.48      0.48      0.47       465

# %%
from sklearn.metrics import roc_curve
fpr_keras, tpr_keras, thresholds_keras = roc_curve(val_gen_aug.classes, predictions)

# %%
from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

plt.figure(2)
plt.xlim(0.0, 0.2)
plt.ylim(0.65, 0.9)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (zoomed in at top left)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # EfficientNet with Augmentation

# %%
weight_path="{}_weights.best.hdf5".format('best_efficientnet0_elbow_classifier')

checkpoint3 = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)


reduceLROnPlat3 = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto', min_lr=0.000001)
#epsilon=0.0001, cooldown=5
early3 = EarlyStopping(monitor='val_loss', patience=10, verbose=1, min_delta=1e-4) # probably needs to be more patient, but kaggle time is limited
callbacks_list_3 = [checkpoint3, early3, reduceLROnPlat3]

opt=keras.optimizers.Adam(learning_rate=0.001)
model19=Sequential()
model19.add(efn.EfficientNetB0(include_top=False,weights='imagenet',input_shape=(224,224,3),pooling='avg'))
model19.add(Flatten())
model19.add(Dense(1, activation='sigmoid'))
model19.compile(loss='binary_crossentropy',optimizer=opt,metrics = ['accuracy','mse'])
model19.summary()

history19=model19.fit(train_gen_aug,validation_data=val_gen_aug,epochs=30,callbacks=callbacks_list_3,shuffle=True)
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 16809984/16804768 [==============================] - 1s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b0 (Functional) (None, 1280)              4049564
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1281
# =================================================================
# Total params: 4,050,845
# Trainable params: 4,008,829
# Non-trainable params: 42,016
# _________________________________________________________________
# Epoch 1/30
# 617/617 [==============================] - ETA: 0s - loss: 0.5859 - accuracy: 0.7112 - mse: 0.1969
# Epoch 00001: val_loss improved from inf to 0.58170, saving model to best_efficientnet0_elbow_classifier_weights.best.hdf5
# 617/617 [==============================] - 85s 137ms/step - loss: 0.5859 - accuracy: 0.7112 - mse: 0.1969 - val_loss: 0.5817 - val_accuracy: 0.7161 - val_mse: 0.1984
# Epoch 2/30
# 617/617 [==============================] - ETA: 0s - loss: 0.5083 - accuracy: 0.7737 - mse: 0.1652
# Epoch 00002: val_loss improved from 0.58170 to 0.48692, saving model to best_efficientnet0_elbow_classifier_weights.best.hdf5
# 617/617 [==============================] - 82s 133ms/step - loss: 0.5083 - accuracy: 0.7737 - mse: 0.1652 - val_loss: 0.4869 - val_accuracy: 0.7677 - val_mse: 0.1586
# Epoch 3/30
# 617/617 [==============================] - ETA: 0s - loss: 0.4804 - accuracy: 0.7844 - mse: 0.1549
# Epoch 00003: val_loss improved from 0.48692 to 0.43938, saving model to best_efficientnet0_elbow_classifier_weights.best.hdf5
# 617/617 [==============================] - 81s 131ms/step - loss: 0.4804 - accuracy: 0.7844 - mse: 0.1549 - val_loss: 0.4394 - val_accuracy: 0.7935 - val_mse: 0.1410
# Epoch 00012: val_loss did not improve from 0.36455
# 617/617 [==============================] - 83s 135ms/step - loss: 0.3084 - accuracy: 0.8779 - mse: 0.0933 - val_loss: 0.3694 - val_accuracy: 0.8516 - val_mse: 0.1136
# Epoch 13/30
# 617/617 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.8781 - mse: 0.0914
# Epoch 00013: val_loss did not improve from 0.36455
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 617/617 [==============================] - 83s 135ms/step - loss: 0.3023 - accuracy: 0.8781 - mse: 0.0914 - val_loss: 0.3958 - val_accuracy: 0.8215 - val_mse: 0.1277
# Epoch 14/30
# 617/617 [==============================] - ETA: 0s - loss: 0.2893 - accuracy: 0.8874 - mse: 0.0866
# Epoch 00014: val_loss did not improve from 0.36455
# 617/617 [==============================] - 83s 134ms/step - loss: 0.2893 - accuracy: 0.8874 - mse: 0.0866 - val_loss: 0.3775 - val_accuracy: 0.8301 - val_mse: 0.1170
# Epoch 15/30
# 617/617 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.8812 - mse: 0.0868
# Epoch 00015: val_loss did not improve from 0.36455
# 617/617 [==============================] - 83s 134ms/step - loss: 0.2863 - accuracy: 0.8812 - mse: 0.0868 - val_loss: 0.3752 - val_accuracy: 0.8473 - val_mse: 0.1151
# Epoch 16/30
# 617/617 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.8870 - mse: 0.0841
# Epoch 00016: val_loss did not improve from 0.36455
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 617/617 [==============================] - 83s 135ms/step - loss: 0.2817 - accuracy: 0.8870 - mse: 0.0841 - val_loss: 0.3846 - val_accuracy: 0.8301 - val_mse: 0.1221
# Epoch 17/30
# 617/617 [==============================] - ETA: 0s - loss: 0.2798 - accuracy: 0.8832 - mse: 0.0848
# Epoch 00017: val_loss did not improve from 0.36455
# 617/617 [==============================] - 83s 134ms/step - loss: 0.2798 - accuracy: 0.8832 - mse: 0.0848 - val_loss: 0.3790 - val_accuracy: 0.8473 - val_mse: 0.1173
# Epoch 18/30
# 617/617 [==============================] - ETA: 0s - loss: 0.2820 - accuracy: 0.8897 - mse: 0.0849
# Epoch 00018: val_loss did not improve from 0.36455
# 617/617 [==============================] - 82s 133ms/step - loss: 0.2820 - accuracy: 0.8897 - mse: 0.0849 - val_loss: 0.3814 - val_accuracy: 0.8452 - val_mse: 0.1173
# Epoch 19/30
# 617/617 [==============================] - ETA: 0s - loss: 0.2738 - accuracy: 0.8915 - mse: 0.0820
# Epoch 00019: val_loss did not improve from 0.36455
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1e-06.
# 617/617 [==============================] - 82s 133ms/step - loss: 0.2738 - accuracy: 0.8915 - mse: 0.0820 - val_loss: 0.3648 - val_accuracy: 0.8409 - val_mse: 0.1143
# Epoch 20/30
# 617/617 [==============================] - ETA: 0s - loss: 0.2806 - accuracy: 0.8870 - mse: 0.0846
# Epoch 00020: val_loss did not improve from 0.36455
# 617/617 [==============================] - 83s 134ms/step - loss: 0.2806 - accuracy: 0.8870 - mse: 0.0846 - val_loss: 0.3917 - val_accuracy: 0.8409 - val_mse: 0.1231
# Epoch 00020: early stopping

# %%
from google.colab import files
files.download("best_efficientnet0_elbow_classifier_weights.best.hdf5")
