# %% [markdown]
# # Training Classifier Hand

# %%
# !pip install -U --pre efficientnet
# Out:
# Collecting efficientnet
#   Downloading https://files.pythonhosted.org/packages/53/97/84f88e581d6ac86dcf1ab347c497c4c568c38784e3a2bd659b96912ab793/efficientnet-1.1.1-py3-none-any.whl
# Collecting keras-applications<=1.0.8,>=1.0.7
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 4.8MB/s
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet) (0.16.2)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.18.5)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (2.4.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (3.2.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (1.4.1)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (1.1.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (2.5)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet) (7.0.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.15.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.4.7)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet) (1.2.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet) (4.4.2)
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import tensorflow as tf
import cv2

import seaborn as sns
from PIL import Image

from tqdm import tqdm_notebook,tqdm


from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16,preprocess_input,decode_predictions
from keras.layers import  Convolution2D,MaxPooling2D,Dense,Flatten,Dropout,GlobalMaxPooling1D
from keras.layers import AveragePooling2D
from keras.models import  Sequential
import imutils
from keras.applications.resnet import ResNet50,ResNet152,preprocess_input,decode_predictions
from keras.applications.densenet import DenseNet121,DenseNet169,preprocess_input,decode_predictions
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
import efficientnet.keras as efn

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Generating MetaDataframes

# %%
def returnDf(bodypart,path):

  train_imgs_path=pd.read_csv(path+'MURA-v1.1/train_image_paths.csv',names=['img_path'])
  test_imgs_path=pd.read_csv(path+'MURA-v1.1/valid_image_paths.csv',names=['img_path'])


  train_imgs_path['Body_Part']=train_imgs_path['img_path'].apply(lambda x: str(x.split('/')[2])[3:])
  train_imgs_path['Study_No']=train_imgs_path['img_path'].apply(lambda x: str(x.split('/')[4])[:6])
  train_imgs_path['label']=train_imgs_path['img_path'].apply(lambda x: str(x.split('/')[4])[7:])

  test_imgs_path['Body_Part']=test_imgs_path['img_path'].apply(lambda x: str(x.split('/')[2])[3:])
  test_imgs_path['Study_No']=test_imgs_path['img_path'].apply(lambda x: str(x.split('/')[4])[:6])
  test_imgs_path['label']=test_imgs_path['img_path'].apply(lambda x: str(x.split('/')[4])[7:])


  train_df=train_imgs_path[train_imgs_path['Body_Part']==bodypart]
  test_df=test_imgs_path[test_imgs_path['Body_Part']==bodypart]

  train_df['img_path']=[path + i for i in train_df['img_path']]
  test_df['img_path']=[path + i for i in test_df['img_path']]
  
  #train_labels['Body_Part']=train_labels['img_path'].apply(lambda x: str(x.split('/')[2])[3:])
  #train_labels['Study_Type']=train_labels['img_path'].apply(lambda x: str(x.split('/')[4])[:6])
  #test_labels['Body_Part']=test_labels['img_path'].apply(lambda x: str(x.split('/')[2])[3:])
  #test_labels['Study_Type']=test_labels['img_path'].apply(lambda x: str(x.split('/')[4])[:6])


  #train_labels['img_path']=train_imgs_path.iloc[:,0]
  #test_labels['img_path']=test_imgs_path.iloc[:,0]
    
  #train_df=train_labels[train_labels['Body_Part']==bodypart]
  #test_df=test_labels[test_labels['Body_Part']==bodypart]
  #train_df['img_path']=[path + i for i in train_df['img_path']]
  #train_df['label']=train_df['label'].astype('str')
  #test_df['img_path']=[path + i for i in test_df['img_path']]
  #test_df['label']=test_df['label'].astype('str')
  train_df['label']=[str(1) if i=='positive' else str(0) for i in train_df['label']]
  test_df['label']=[str(1) if i=='positive' else str(0) for i in test_df['label']]

  return train_df, test_df

# %%
train_df,test_df=returnDf('HAND','gdrive/My Drive/Capstone Medical Imaging/Data.nosync/')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_df.head()
# Out:
#                                                 img_path  ... label
# 31265  gdrive/My Drive/Capstone Medical Imaging/Data....  ...     1
# 31266  gdrive/My Drive/Capstone Medical Imaging/Data....  ...     1
# 31267  gdrive/My Drive/Capstone Medical Imaging/Data....  ...     1
# 31268  gdrive/My Drive/Capstone Medical Imaging/Data....  ...     1
# 31269  gdrive/My Drive/Capstone Medical Imaging/Data....  ...     1
#
# [5 rows x 4 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5543 entries, 31265 to 36807
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   img_path   5543 non-null   object
#  1   Body_Part  5543 non-null   object
#  2   Study_No   5543 non-null   object
#  3   label      5543 non-null   object
# dtypes: object(4)
# memory usage: 216.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 460 entries, 960 to 1419
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   img_path   460 non-null    object
#  1   Body_Part  460 non-null    object
#  2   Study_No   460 non-null    object
#  3   label      460 non-null    object
# dtypes: object(4)
# memory usage: 18.0+ KB

# %%
 train_df['img_path'].iloc[1]
# Out:
# 'gdrive/My Drive/Capstone Medical Imaging/Data.nosync/MURA-v1.1/train/XR_HAND/patient09734/study1_positive/image2.png'

# %%
train_df['label'].value_counts()
# Out:
# 0    4059
# 1    1484
# Name: label, dtype: int64

# %%
test_df['label'].value_counts()
# Out:
# 0    271
# 1    189
# Name: label, dtype: int64

# %% [markdown]
# Baseline accuracy on training is 59%

# %%
mean_imagenet = [0.485, 0.456, 0.406]
std_imagenet = [0.229, 0.224, 0.225]

# %%
train_df.head().iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x7f37e0537af0>

# %%
fig,ax=plt.subplots(5,2,sharey=True,figsize=(20,100))
image_dict={}
image_dict['images']=[]
image_dict['label']=[]
count=0
for index,row in tqdm(train_df.head().iterrows()):
  img_arr=cv2.imread(row['img_path'])
  ax[count,0].imshow(img_arr)
  
  resized_arr=cv2.resize(img_arr,(224,224))
  
  ax[count,1].imshow(resized_arr)
  count+=1
                     
  

#image_dict['images']=(image_dict['images']-mean_imagenet)/std_imagenet
# Out:
# 5it [00:12,  2.57s/it]

# %% [markdown]
# # Creating image generators with simple preprocessing and options for data augmentation

# %%
def returnImgGen(train_df,test_df,IMG_SIZE=(224,224),rotation_range=0,horizontal_flip=False):
  datagen=ImageDataGenerator(
    horizontal_flip=horizontal_flip,
    #vertical_flip=True,
    rotation_range=rotation_range,
    #fill_mode='nearest',
    #preprocessing_function=preprocess_input)
    rescale=1./255.)



  train_gen=datagen.flow_from_dataframe(train_df,
                           x_col='img_path',
                           y_col='label',
                           target_size=IMG_SIZE,
                           color_mode='rgb',
                           class_mode='binary',batch_size=8,seed=101)

  
    
  val_gen=datagen.flow_from_dataframe(test_df,
                           x_col='img_path',
                           y_col='label',
                           target_size=IMG_SIZE,
                           color_mode='rgb',
                           class_mode='binary', batch_size=1,seed=101)
    
    
  return train_gen, val_gen

# %%
train_gen_224,val_gen_224=returnImgGen(train_df,test_df)
# Out:
# Found 5543 validated image filenames belonging to 2 classes.
# Found 460 validated image filenames belonging to 2 classes.

# %%
def plot_val_train_loss(hist):
  loss_train = hist.history['loss']
  loss_val = hist.history['val_loss']
  epochs = range(1,len(hist.history['val_loss'])+1)
  plt.plot(epochs, loss_train, 'g', label='Training loss')
  plt.plot(epochs, loss_val, 'b', label='validation loss')
  plt.title('Training and Validation loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()

# %% [markdown]
# # Augmented Data Image Generators

# %%
train_gen_aug,val_gen_aug=returnImgGen(train_df,test_df,IMG_SIZE=(224,224),rotation_range=30,horizontal_flip=True)
# Out:
# Found 5543 validated image filenames belonging to 2 classes.
# Found 460 validated image filenames belonging to 2 classes.

# %% [markdown]
# # DenseNet169 with Augmentation

# %%
weight_path="{}_weights.best.hdf5".format('best_densenet_hand_classifier')

checkpoint3 = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)


reduceLROnPlat3 = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto', min_lr=0.000001)
#epsilon=0.0001, cooldown=5
early3 = EarlyStopping(monitor='val_loss', patience=10, verbose=1, min_delta=1e-4) # probably needs to be more patient, but kaggle time is limited
callbacks_list_3 = [checkpoint3, early3, reduceLROnPlat3]

opt=keras.optimizers.Adam(learning_rate=0.001)
model17=Sequential()
model17.add(DenseNet169(include_top=False,weights='imagenet',input_shape=(224,224,3),pooling='avg'))
model17.add(Flatten())
model17.add(Dense(1, activation='sigmoid'))
model17.compile(loss='binary_crossentropy',optimizer=opt,metrics = ['accuracy','mse'])
model17.summary()

history17=model17.fit(train_gen_aug,validation_data=val_gen_aug,epochs=30,callbacks=callbacks_list_3,shuffle=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet169 (Functional)     (None, 1664)              12642880
# _________________________________________________________________
# flatten (Flatten)            (None, 1664)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 1665
# =================================================================
# Total params: 12,644,545
# Trainable params: 12,486,145
# Non-trainable params: 158,400
# _________________________________________________________________
# Epoch 1/30
# 693/693 [==============================] - ETA: 0s - loss: 0.6182 - accuracy: 0.7146 - mse: 0.2075
# Epoch 00001: val_loss improved from inf to 57.08154, saving model to best_densenet_hand_classifier_weights.best.hdf5
# 693/693 [==============================] - 2804s 4s/step - loss: 0.6182 - accuracy: 0.7146 - mse: 0.2075 - val_loss: 57.0815 - val_accuracy: 0.5891 - val_mse: 0.3601
# Epoch 2/30
# 693/693 [==============================] - ETA: 0s - loss: 0.6019 - accuracy: 0.7269 - mse: 0.2026
# Epoch 00002: val_loss improved from 57.08154 to 3.91453, saving model to best_densenet_hand_classifier_weights.best.hdf5
# 693/693 [==============================] - 102s 147ms/step - loss: 0.6019 - accuracy: 0.7269 - mse: 0.2026 - val_loss: 3.9145 - val_accuracy: 0.5783 - val_mse: 0.3928
# Epoch 3/30
# 693/693 [==============================] - ETA: 0s - loss: 0.6018 - accuracy: 0.7256 - mse: 0.2030
# Epoch 00003: val_loss improved from 3.91453 to 0.75383, saving model to best_densenet_hand_classifier_weights.best.hdf5
# 693/693 [==============================] - 101s 146ms/step - loss: 0.6018 - accuracy: 0.7256 - mse: 0.2030 - val_loss: 0.7538 - val_accuracy: 0.5891 - val_mse: 0.2733
# Epoch 4/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5986 - accuracy: 0.7252 - mse: 0.2020
# Epoch 00004: val_loss improved from 0.75383 to 0.74721, saving model to best_densenet_hand_classifier_weights.best.hdf5
# 693/693 [==============================] - 101s 146ms/step - loss: 0.5986 - accuracy: 0.7252 - mse: 0.2020 - val_loss: 0.7472 - val_accuracy: 0.5891 - val_mse: 0.2690
# Epoch 5/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5880 - accuracy: 0.7305 - mse: 0.1981
# Epoch 00005: val_loss improved from 0.74721 to 0.69453, saving model to best_densenet_hand_classifier_weights.best.hdf5
# 693/693 [==============================] - 102s 147ms/step - loss: 0.5880 - accuracy: 0.7305 - mse: 0.1981 - val_loss: 0.6945 - val_accuracy: 0.5891 - val_mse: 0.2385
# Epoch 6/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5814 - accuracy: 0.7301 - mse: 0.1956
# Epoch 00006: val_loss did not improve from 0.69453
# 693/693 [==============================] - 101s 146ms/step - loss: 0.5814 - accuracy: 0.7301 - mse: 0.1956 - val_loss: 0.7115 - val_accuracy: 0.5891 - val_mse: 0.2534
# Epoch 7/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5840 - accuracy: 0.7308 - mse: 0.1967
# Epoch 00007: val_loss did not improve from 0.69453
# 693/693 [==============================] - 101s 146ms/step - loss: 0.5840 - accuracy: 0.7308 - mse: 0.1967 - val_loss: 0.7568 - val_accuracy: 0.5891 - val_mse: 0.2436
# Epoch 8/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5824 - accuracy: 0.7297 - mse: 0.1959
# Epoch 00008: val_loss did not improve from 0.69453
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 693/693 [==============================] - 101s 146ms/step - loss: 0.5824 - accuracy: 0.7297 - mse: 0.1959 - val_loss: 0.7124 - val_accuracy: 0.5891 - val_mse: 0.2508
# Epoch 9/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5796 - accuracy: 0.7323 - mse: 0.1956
# Epoch 00009: val_loss did not improve from 0.69453
# 693/693 [==============================] - 101s 146ms/step - loss: 0.5796 - accuracy: 0.7323 - mse: 0.1956 - val_loss: 0.7480 - val_accuracy: 0.5891 - val_mse: 0.2655
# Epoch 10/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5789 - accuracy: 0.7323 - mse: 0.1952
# Epoch 00010: val_loss did not improve from 0.69453
# 693/693 [==============================] - 101s 146ms/step - loss: 0.5789 - accuracy: 0.7323 - mse: 0.1952 - val_loss: 0.7096 - val_accuracy: 0.5891 - val_mse: 0.2554
# Epoch 11/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5781 - accuracy: 0.7323 - mse: 0.1949
# Epoch 00011: val_loss did not improve from 0.69453
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 693/693 [==============================] - 101s 146ms/step - loss: 0.5781 - accuracy: 0.7323 - mse: 0.1949 - val_loss: 0.7361 - val_accuracy: 0.5891 - val_mse: 0.2640
# Epoch 12/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5772 - accuracy: 0.7323 - mse: 0.1945
# Epoch 00012: val_loss did not improve from 0.69453
# 693/693 [==============================] - 100s 145ms/step - loss: 0.5772 - accuracy: 0.7323 - mse: 0.1945 - val_loss: 0.7185 - val_accuracy: 0.5891 - val_mse: 0.2589
# Epoch 13/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5763 - accuracy: 0.7323 - mse: 0.1942
# Epoch 00013: val_loss did not improve from 0.69453
# 693/693 [==============================] - 100s 144ms/step - loss: 0.5763 - accuracy: 0.7323 - mse: 0.1942 - val_loss: 0.7191 - val_accuracy: 0.5891 - val_mse: 0.2598
# Epoch 14/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5750 - accuracy: 0.7323 - mse: 0.1938
# Epoch 00014: val_loss did not improve from 0.69453
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 693/693 [==============================] - 101s 145ms/step - loss: 0.5750 - accuracy: 0.7323 - mse: 0.1938 - val_loss: 0.7165 - val_accuracy: 0.5891 - val_mse: 0.2584
# Epoch 15/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5751 - accuracy: 0.7323 - mse: 0.1939
# Epoch 00015: val_loss did not improve from 0.69453
# 693/693 [==============================] - 100s 144ms/step - loss: 0.5751 - accuracy: 0.7323 - mse: 0.1939 - val_loss: 0.7208 - val_accuracy: 0.5891 - val_mse: 0.2586
# Epoch 00015: early stopping

# %%
plot_val_train_loss(history17)

# %%
from google.colab import files
files.download("best_densenet_hand_classifier_weights.best.hdf5")

# %%
model17.load_weights('best_densenet_hand_classifier_weights.best.hdf5')

# %%
Y_pred = model17.predict(val_gen_aug)

# %%
predictions = []
for p in Y_pred:
    if(p > 0.5):
        predictions+=[1]
    else:
        predictions+=[0]

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print('Confusion Matrix')
print(confusion_matrix(val_gen_aug.classes, predictions))
print('Classification Report')
target_names = ['Normal','Abnormal']
print(classification_report(val_gen_aug.classes, predictions, target_names=target_names))
# Out:
# Confusion Matrix
# [[257  14]
#  [180   9]]
# Classification Report
#               precision    recall  f1-score   support
#
#       Normal       0.59      0.95      0.73       271
#     Abnormal       0.39      0.05      0.08       189
#
#     accuracy                           0.58       460
#    macro avg       0.49      0.50      0.41       460
# weighted avg       0.51      0.58      0.46       460

# %%
from sklearn.metrics import roc_curve
fpr_keras, tpr_keras, thresholds_keras = roc_curve(val_gen_aug.classes, predictions)

# %%
from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

plt.figure(2)
plt.xlim(0.0, 0.2)
plt.ylim(0.65, 0.9)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (zoomed in at top left)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # EfficientNet with Augmentation

# %%
weight_path="{}_weights.best.hdf5".format('best_efficientnet0_finger_classifier')

checkpoint3 = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)


reduceLROnPlat3 = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, mode='auto', min_lr=0.000001)
#epsilon=0.0001, cooldown=5
early3 = EarlyStopping(monitor='val_loss', patience=10, verbose=1, min_delta=1e-4) # probably needs to be more patient, but kaggle time is limited
callbacks_list_3 = [checkpoint3, early3, reduceLROnPlat3]

opt=keras.optimizers.Adam(learning_rate=0.001)
model19=Sequential()
model19.add(efn.EfficientNetB0(include_top=False,weights='imagenet',input_shape=(224,224,3),pooling='avg'))
model19.add(Flatten())
model19.add(Dense(1, activation='sigmoid'))
model19.compile(loss='binary_crossentropy',optimizer=opt,metrics = ['accuracy','mse'])
model19.summary()

history19=model19.fit(train_gen_aug,validation_data=val_gen_aug,epochs=30,callbacks=callbacks_list_3,shuffle=True)
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b0_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 16809984/16804768 [==============================] - 1s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b0 (Functional) (None, 1280)              4049564
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1281
# =================================================================
# Total params: 4,050,845
# Trainable params: 4,008,829
# Non-trainable params: 42,016
# _________________________________________________________________
# Epoch 1/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5854 - accuracy: 0.7251 - mse: 0.1954
# Epoch 00001: val_loss improved from inf to 0.64252, saving model to best_efficientnet0_finger_classifier_weights.best.hdf5
# 693/693 [==============================] - 102s 147ms/step - loss: 0.5854 - accuracy: 0.7251 - mse: 0.1954 - val_loss: 0.6425 - val_accuracy: 0.6435 - val_mse: 0.2256
# Epoch 2/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.7472 - mse: 0.1783
# Epoch 00002: val_loss did not improve from 0.64252
# 693/693 [==============================] - 100s 145ms/step - loss: 0.5392 - accuracy: 0.7472 - mse: 0.1783 - val_loss: 0.9206 - val_accuracy: 0.6283 - val_mse: 0.2933
# Epoch 3/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5238 - accuracy: 0.7590 - mse: 0.1717
# Epoch 00003: val_loss improved from 0.64252 to 0.58216, saving model to best_efficientnet0_finger_classifier_weights.best.hdf5
# 693/693 [==============================] - 100s 145ms/step - loss: 0.5238 - accuracy: 0.7590 - mse: 0.1717 - val_loss: 0.5822 - val_accuracy: 0.7304 - val_mse: 0.1880
# Epoch 4/30
# 693/693 [==============================] - ETA: 0s - loss: 0.5054 - accuracy: 0.7693 - mse: 0.1644
# Epoch 00004: val_loss did not improve from 0.58216
# 693/693 [==============================] - 100s 145ms/step - loss: 0.5054 - accuracy: 0.7693 - mse: 0.1644 - val_loss: 0.6688 - val_accuracy: 0.6587 - val_mse: 0.2316
# Epoch 5/30
# 693/693 [==============================] - ETA: 0s - loss: 0.4917 - accuracy: 0.7792 - mse: 0.1590
# Epoch 00005: val_loss did not improve from 0.58216
# 693/693 [==============================] - 100s 145ms/step - loss: 0.4917 - accuracy: 0.7792 - mse: 0.1590 - val_loss: 0.8624 - val_accuracy: 0.6609 - val_mse: 0.2579
# Epoch 6/30
# 693/693 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.7835 - mse: 0.1572
# Epoch 00006: val_loss did not improve from 0.58216
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 693/693 [==============================] - 100s 145ms/step - loss: 0.4876 - accuracy: 0.7835 - mse: 0.1572 - val_loss: 0.7533 - val_accuracy: 0.6522 - val_mse: 0.2501
# Epoch 7/30
# 693/693 [==============================] - ETA: 0s - loss: 0.4449 - accuracy: 0.8131 - mse: 0.1407
# Epoch 00007: val_loss improved from 0.58216 to 0.57720, saving model to best_efficientnet0_finger_classifier_weights.best.hdf5
# 693/693 [==============================] - 101s 145ms/step - loss: 0.4449 - accuracy: 0.8131 - mse: 0.1407 - val_loss: 0.5772 - val_accuracy: 0.7630 - val_mse: 0.1768
# Epoch 8/30
# 693/693 [==============================] - ETA: 0s - loss: 0.4267 - accuracy: 0.8205 - mse: 0.1339
# Epoch 00008: val_loss improved from 0.57720 to 0.54611, saving model to best_efficientnet0_finger_classifier_weights.best.hdf5
# 693/693 [==============================] - 101s 145ms/step - loss: 0.4267 - accuracy: 0.8205 - mse: 0.1339 - val_loss: 0.5461 - val_accuracy: 0.7674 - val_mse: 0.1704
# Epoch 9/30
# 693/693 [==============================] - ETA: 0s - loss: 0.4131 - accuracy: 0.8319 - mse: 0.1284
# Epoch 00009: val_loss did not improve from 0.54611
# 693/693 [==============================] - 101s 145ms/step - loss: 0.4131 - accuracy: 0.8319 - mse: 0.1284 - val_loss: 0.5550 - val_accuracy: 0.7652 - val_mse: 0.1753
# Epoch 10/30
# 693/693 [==============================] - ETA: 0s - loss: 0.4036 - accuracy: 0.8366 - mse: 0.1252
# Epoch 00010: val_loss improved from 0.54611 to 0.52033, saving model to best_efficientnet0_finger_classifier_weights.best.hdf5
# 693/693 [==============================] - 101s 145ms/step - loss: 0.4036 - accuracy: 0.8366 - mse: 0.1252 - val_loss: 0.5203 - val_accuracy: 0.7848 - val_mse: 0.1636
# Epoch 11/30
# 693/693 [==============================] - ETA: 0s - loss: 0.4013 - accuracy: 0.8333 - mse: 0.1244
# Epoch 00011: val_loss did not improve from 0.52033
# 693/693 [==============================] - 101s 146ms/step - loss: 0.4013 - accuracy: 0.8333 - mse: 0.1244 - val_loss: 0.5301 - val_accuracy: 0.7761 - val_mse: 0.1689
# Epoch 12/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3911 - accuracy: 0.8375 - mse: 0.1210
# Epoch 00012: val_loss did not improve from 0.52033
# 693/693 [==============================] - 101s 146ms/step - loss: 0.3911 - accuracy: 0.8375 - mse: 0.1210 - val_loss: 0.5452 - val_accuracy: 0.7674 - val_mse: 0.1736
# Epoch 13/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3859 - accuracy: 0.8393 - mse: 0.1188
# Epoch 00013: val_loss did not improve from 0.52033
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 693/693 [==============================] - 101s 146ms/step - loss: 0.3859 - accuracy: 0.8393 - mse: 0.1188 - val_loss: 0.5436 - val_accuracy: 0.7630 - val_mse: 0.1695
# Epoch 14/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3754 - accuracy: 0.8468 - mse: 0.1154
# Epoch 00014: val_loss improved from 0.52033 to 0.49988, saving model to best_efficientnet0_finger_classifier_weights.best.hdf5
# 693/693 [==============================] - 101s 146ms/step - loss: 0.3754 - accuracy: 0.8468 - mse: 0.1154 - val_loss: 0.4999 - val_accuracy: 0.7848 - val_mse: 0.1592
# Epoch 15/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3705 - accuracy: 0.8497 - mse: 0.1134
# Epoch 00015: val_loss did not improve from 0.49988
# 693/693 [==============================] - 100s 144ms/step - loss: 0.3705 - accuracy: 0.8497 - mse: 0.1134 - val_loss: 0.5159 - val_accuracy: 0.7935 - val_mse: 0.1612
# Epoch 16/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3665 - accuracy: 0.8501 - mse: 0.1121
# Epoch 00016: val_loss did not improve from 0.49988
# 693/693 [==============================] - 100s 144ms/step - loss: 0.3665 - accuracy: 0.8501 - mse: 0.1121 - val_loss: 0.5170 - val_accuracy: 0.7935 - val_mse: 0.1603
# Epoch 17/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3679 - accuracy: 0.8508 - mse: 0.1127
# Epoch 00017: val_loss did not improve from 0.49988
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 693/693 [==============================] - 101s 146ms/step - loss: 0.3679 - accuracy: 0.8508 - mse: 0.1127 - val_loss: 0.5060 - val_accuracy: 0.7826 - val_mse: 0.1624
# Epoch 18/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.8501 - mse: 0.1136
# Epoch 00018: val_loss did not improve from 0.49988
# 693/693 [==============================] - 100s 145ms/step - loss: 0.3711 - accuracy: 0.8501 - mse: 0.1136 - val_loss: 0.5136 - val_accuracy: 0.7870 - val_mse: 0.1594
# Epoch 19/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3657 - accuracy: 0.8537 - mse: 0.1118
# Epoch 00019: val_loss did not improve from 0.49988
# 693/693 [==============================] - 100s 145ms/step - loss: 0.3657 - accuracy: 0.8537 - mse: 0.1118 - val_loss: 0.5093 - val_accuracy: 0.8065 - val_mse: 0.1579
# Epoch 20/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3625 - accuracy: 0.8501 - mse: 0.1117
# Epoch 00020: val_loss did not improve from 0.49988
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1e-06.
# 693/693 [==============================] - 101s 146ms/step - loss: 0.3625 - accuracy: 0.8501 - mse: 0.1117 - val_loss: 0.5237 - val_accuracy: 0.7870 - val_mse: 0.1633
# Epoch 21/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.8533 - mse: 0.1095
# Epoch 00021: val_loss did not improve from 0.49988
# 693/693 [==============================] - 100s 144ms/step - loss: 0.3586 - accuracy: 0.8533 - mse: 0.1095 - val_loss: 0.5269 - val_accuracy: 0.7739 - val_mse: 0.1657
# Epoch 22/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3656 - accuracy: 0.8544 - mse: 0.1119
# Epoch 00022: val_loss did not improve from 0.49988
# 693/693 [==============================] - 100s 145ms/step - loss: 0.3656 - accuracy: 0.8544 - mse: 0.1119 - val_loss: 0.5234 - val_accuracy: 0.7826 - val_mse: 0.1641
# Epoch 23/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.8506 - mse: 0.1112
# Epoch 00023: val_loss did not improve from 0.49988
# 693/693 [==============================] - 100s 144ms/step - loss: 0.3614 - accuracy: 0.8506 - mse: 0.1112 - val_loss: 0.5057 - val_accuracy: 0.8043 - val_mse: 0.1574
# Epoch 24/30
# 693/693 [==============================] - ETA: 0s - loss: 0.3631 - accuracy: 0.8530 - mse: 0.1112
# Epoch 00024: val_loss did not improve from 0.49988
# 693/693 [==============================] - 100s 144ms/step - loss: 0.3631 - accuracy: 0.8530 - mse: 0.1112 - val_loss: 0.5184 - val_accuracy: 0.7783 - val_mse: 0.1638
# Epoch 00024: early stopping

# %%
from google.colab import files
files.download("best_efficientnet0_finger_classifier_weights.best.hdf5")
